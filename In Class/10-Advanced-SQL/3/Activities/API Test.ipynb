# %%
import requests 
import pandas as pd

# %%
res = requests.get('http://127.0.0.1:5000/api/mammal/status/extant')

# %%
res.json()
# Out:
# [{'family': 'Antilocapridae',
#   'genus': 'Antilocapra',
#   'order': 'Artiodactyla',
#   'species': 'americana',
#   'status': 'extant'},
#  {'family': 'Bovidae',
#   'genus': 'Bison',
#   'order': 'Artiodactyla',
#   'species': 'bison',
#   'status': 'extant'},
#  {'family': 'Bovidae',
#   'genus': 'Oreamnos',
#   'order': 'Artiodactyla',
#   'species': 'americanus',
#   'status': 'extant'},
#  {'family': 'Bovidae',
#   'genus': 'Ovibos',
#   'order': 'Artiodactyla',
#   'species': 'moschatus',
#   'status': 'extant'},
#  {'family': 'Bovidae',
#   'genus': 'Ovis',
#   'order': 'Artiodactyla',
#   'species': 'canadensis',
#   'status': 'extant'},
#  {'family': 'Bovidae',
#   'genus': 'Ovis',
#   'order': 'Artiodactyla',
#   'species': 'dalli',
#   'status': 'extant'},
#  {'family': 'Cervidae',
#   'genus': 'Alces',
#   'order': 'Artiodactyla',
#   'species': 'alces',
#   'status': 'extant'},
#  {'family': 'Cervidae',
#   'genus': 'Cervus',
#   'order': 'Artiodactyla',
# ...

# %%
pd.DataFrame(res.json())
# Out:
#               family         genus         order       species  status
# 0     Antilocapridae   Antilocapra  Artiodactyla     americana  extant
# 1            Bovidae         Bison  Artiodactyla         bison  extant
# 2            Bovidae      Oreamnos  Artiodactyla    americanus  extant
# 3            Bovidae        Ovibos  Artiodactyla     moschatus  extant
# 4            Bovidae          Ovis  Artiodactyla    canadensis  extant
# ..               ...           ...           ...           ...     ...
# 695      Dasypodidae       Dasypus     Xenarthra  novemcinctus  extant
# 696   Megalonychidae     Choloepus     Xenarthra     hoffmanni  extant
# 697  Myrmecophagidae      Cyclopes     Xenarthra    didactylus  extant
# 698  Myrmecophagidae  Myrmecophaga     Xenarthra    tridactyla  extant
# 699  Myrmecophagidae      Tamandua     Xenarthra      mexicana  extant
#
# [700 rows x 5 columns]
