# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

database_path = "../Resources/Census_Data.sqlite"

# %%
# Create Engine
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
data = engine.execute("select * from Census_Data")

# %%
pd.DataFrame(data)
# Out:
#                         0                  1   2        3        4       5   \
# 0              HOUSTON, TX            HOUSTON  TX  3061887  1775897  684416
# 1              CHICAGO, IL            CHICAGO  IL  2702091  1318869  843633
# 2             BROOKLYN, NY           BROOKLYN  NY  2595259  1126111  870465
# 3          LOS ANGELES, CA        LOS ANGELES  CA  2426413  1068202  324842
# 4                MIAMI, FL              MIAMI  FL  1820704  1361009  363514
# ..                     ...                ...  ..      ...      ...     ...
# 994  ALTAMONTE SPRINGS, FL  ALTAMONTE SPRINGS  FL    56883    42747    9599
# 995        CHILLICOTHE, OH        CHILLICOTHE  OH    56783    50065    3842
# 996         FARMINGTON, NM         FARMINGTON  NM    56781    35887     448
# 997          FAIRFIELD, CT          FAIRFIELD  CT    56704    50515     946
# 998   DEARBORN HEIGHTS, MI   DEARBORN HEIGHTS  MI    56656    47746    4856
#
#         6       7        8      9   ...     21         22         23  \
# 0    11586  230549  1368287  54180  ...  22637  33.439583  32.550000
# 1     7554  161478   785374  32800  ...  18209  34.526786  33.798214
# 2     8744  297890   509243  48934  ...  14845  35.175676  33.367568
# 3    15949  273829  1292382  62684  ...  12329  35.335484  34.535484
# 4     2250   33144  1162711  27137  ...   6969  38.740741  37.120370
# ..     ...     ...      ...    ...  ...    ...        ...        ...
# 994      8    1629    13925    504  ...    397  40.800000  39.500000
# 995     27     398      689    577  ...    356  40.400000  39.100000
# 996  14425     298    13550    425  ...    325  34.333333  34.066667
# 997      8    2777     3337    140  ...    367  40.150000  39.250000
# 998    338    1108     2371    745  ...    186  38.400000  38.300000
#
#             24            25           26           27           28  \
# 0    34.363542   56206.50000  32239.52083   956.708333  178233.6842
# 1    35.141071   57735.96429  38730.83929  1119.928571  264739.2857
# 2    36.578378   51469.18919  28309.67568  1261.783784  605743.2432
# 3    36.061290   47494.58333  30073.19355  1201.766667  557115.0000
# 4    40.262963   51232.90741  25949.35185  1260.833333  243279.6296
# ..         ...           ...          ...          ...          ...
# 994  42.500000   49270.00000  26841.00000  1008.500000  137250.0000
# 995  42.300000   43460.00000  21112.00000   672.000000  112500.0000
# 996  35.500000   48492.66667  22886.66667   978.500000  151933.3333
# 997  41.400000  119230.50000  55042.00000  1679.000000  556600.0000
# 998  38.650000   45113.00000  21787.00000   947.500000   84050.0000
#
#             29          30
# 0    29.775734  -95.414548
# 1    41.867838  -87.673440
# 2    40.652805  -73.956528
# 3    34.042209 -118.303468
# 4    25.760268  -80.298511
# ..         ...         ...
# 994  28.664100  -81.391002
# 995  39.312060  -82.957071
# 996  36.622898 -108.179508
# 997  41.184811  -73.262036
# 998  42.306564  -83.274064
#
# [999 rows x 31 columns]
