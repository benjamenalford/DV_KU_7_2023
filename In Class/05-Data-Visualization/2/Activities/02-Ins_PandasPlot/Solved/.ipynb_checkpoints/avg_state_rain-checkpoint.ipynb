# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Millimetres
# 0      Alaska    43.2         1098
# 1     Alabama    58.9         1495
# 2    Arkansas    55.9         1421
# 3     Arizona    12.6          321
# 4  California    22.2          564

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,4))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0.0, 71.1)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(216.97222222222223, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alaska        43.2
# Alabama       58.9
# Arkansas      55.9
# Arizona       12.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3.5))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36992\860345596.py in <module>
#       1 # Pandas can also plot multiple columns if the DataFrame includes them
# ----> 2 multi_plot = rain_df.plot(kind="pie", figsize=(20,5))
#       3
#       4 # PandasPlot.set_xticklabels() can be used to set the tick labels as well
#       5 multi_plot.set_xticklabels(rain_df["State"], rotation=45)
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     797                 if y is None and kwargs.get("subplots") is False:
#     798                     raise ValueError(
# --> 799                         f"{kind} requires either y column or 'subplots=True'"
#     800                     )
#     801                 elif y is not None:
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
rain_df.reset_index(drop=False)
# Out:
#     index           State  Inches  Millimetres
# 0       0          Alaska    43.2         1098
# 1       1         Alabama    58.9         1495
# 2       2        Arkansas    55.9         1421
# 3       3         Arizona    12.6          321
# 4       4      California    22.2          564
# 5       5        Colorado    18.9          481
# 6       6     Connecticut    50.3         1278
# 7       7        Delaware    49.0         1245
# 8       8         Florida    55.1         1400
# 9       9         Georgia    52.7         1338
# 10     10          Hawaii    58.2         1478
# 11     11            Iowa    38.7          983
# 12     12           Idaho    26.8          681
# 13     13        Illinois    43.1         1096
# 14     14         Indiana    45.9         1165
# 15     15          Kansas    31.5          800
# 16     16        Kentucky    53.8         1367
# 17     17       Louisiana    61.1         1552
# 18     18   Massachusetts    49.8         1266
# 19     19        Maryland    48.5         1231
# 20     20           Maine    49.5         1258
# 21     21        Michigan    36.4          925
# 22     22       Minnesota    31.4          796
# 23     23        Missouri    45.7         1162
# 24     24     Mississippi    60.8         1543
# 25     25         Montana    22.0          559
# 26     26  North Carolina    53.4         1356
# 27     27    North Dakota    19.8          502
# 28     28        Nebraska    26.7          679
# 29     29   New Hampshire    49.3         1253
# 30     30      New Jersey    51.2         1301
# 31     31      New Mexico    13.7          347
# 32     32          Nevada    13.9          352
# 33     33        New York    44.8         1138
# 34     34            Ohio    43.2         1096
# 35     35        Oklahoma    36.4          924
# 36     36          Oregon    44.6         1132
# 37     37    Pennsylvania    47.6         1208
# 38     38    Rhode Island    50.6         1285
# 39     39  South Carolina    50.4         1281
# 40     40    South Dakota    23.0          585
# 41     41       Tennessee    57.3         1455
# 42     42           Texas    33.3          845
# 43     43            Utah    21.0          533
# 44     44        Virginia    48.0         1220
# 45     45         Vermont    46.5         1181
# 46     46      Washington    49.1         1248
# 47     47       Wisconsin    36.6          929
# 48     48   West Virginia    48.2         1224
# 49     49         Wyoming    19.8          502
