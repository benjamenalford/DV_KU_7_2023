# %%
# !pip install webdriver-manager

# %%
from splinter import Browser
from bs4 import BeautifulSoup 
# selenium 4
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.chrome.service import Service

# %%
# Set up Splinter
#browser = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
my_service = ChromeService(executable_path=ChromeDriverManager().install())

# %%
browser = Browser('chrome', service=my_service)

# %%
browser.visit('https://www.espn.com/')

# %%
browser.html
# Out:
# '<html class="js no-touch history cssanimations video localstorage desktop-ua  scrollbars-17 desktop" lang="en" style=""><head><script src="//static.chartbeat.com/js/chartbeat_video.js"></script><script src="https://connect.facebook.net/signals/config/504412503408123?v=2.9.131&amp;r=stable&amp;domain=www.espn.com" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script src="//sb.scorecardresearch.com/cs/3000005/beacon.js"></script><script src="https://secure.espn.com/js/dcf/tags/vision/latest/vision-videojs.js"></script><script async="" src="https://cdn-gl.imrworldwide.com/conf/P07264C85-15CD-4A80-8E56-B5BFA6D93296.js#name=nlsnInstance&amp;ns=NOLBUNDLE"></script><script async="" src="//d.impactradius-event.com/A1323623-ff1f-47da-bf87-01a65620c9c91.js"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/ed391d4d7ebc0ad9228131ded7455a26.js"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/0b62e6477d4c5febd5238c72e8724d4a.js?conditionId0=4924177"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/fd3074bd949b33f162395e014e4b0b3d.js?conditionId0=4905157"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/5387f1846ff8ffde5466713e4415c604.js?conditionId0=4872138"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/2e085528a7cacc092603dfbde20514a6.js?conditionId0=4884623"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/fa7598e370e9aa63237bdc1a926a819e.js?conditionId0=4924895"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/9e28fe21bc200a449c8d356aab69747b.js?conditionId0=4905158"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/ed9cc89e72efe4115d590b2b9169c222.js?conditionId0=4871166"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/d82ac7a01d457b32a7d778423a874d8c.js?conditionId0=4905158"></script><script type="text/javascript" async="" src="https://dcf.espn.com/TWDC-DTCI/prod/code/669b9d6338da06eca5d5375c076e3985.js?conditionId0=4872138"></script><script src="https://dcf.espn.com/TWDC-DTCI/prod/serverComponent.php?namespace=Bootstrapper&amp;staticJsPath=/TWDC-DTCI/prod/code/&amp;publishedOn=Wed Sep 27 17:57:14 GMT 2023&amp;ClientID=2750&amp;PageID=https%3A%2F%2Fwww.espn.com%2F%3Fcds%3Dn%26country%3Dus%26region%3Dccpa%26gpc%3D0%26shouldFire%3Dy%26nAsyncNgeo%3Dn%26portal%3Dsports%26site%3Despn%26siteRegion%3D%26realHost%3Dwww.espn.com%26kpTlium%3Dn&amp;custDomain=dcf.espn.com"></script><script type="text/javascript" src="https://micro.rubiconproject.com/prebid/dynamic/18138.js"></script><script async="" type="text/javascript" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script src="https://scripts.webcontentassessor.com/scripts/a9a1cb5df4050499c2afc338399f0708d6c68d7e2a17750d6eca9313f63844cd"></script>\n\t\t<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<meta http-equiv="x-ua-compatible" content="IE=edge,chrome=1">\n<meta name="viewport" content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n<meta name="referrer" content="origin-when-cross-origin">\n<link rel="canonical" href="https://www.espn.com">\n<title>ESPN - Serving Sports Fans. Anytime. Anywhere.</title>\n<meta name="description" content="Visit ESPN for live scores, highlights and sports news. Stream exclusive games on ESPN+ and play fantasy sports.">\n<link rel="manifest" href="/manifest.json">\n<meta property="fb:app_id" content="116656161708917">\n<meta property="og:site_name" content="ESPN.com">\n<meta property="og:url" content="https://www.espn.com">\n<meta property="og:title" content="ESPN - Serving Sports Fans. Anytime. Anywhere.">\n<meta property="og:description" content ...

# %%
soup = BeautifulSoup(browser.html)

# %%
headline_li = soup.find_all('ul',class_='headlineStack__list')

# %%
for h in headline_li:
    print(h.text.strip())
# Out:
# Lions follow Amon-Ra St. Brown TD with David Montgomery score
# Orioles clinch AL East with 100th win of seasonLeBron prepping for 21st season 'like a rookie'Young fan scores helmet after irate Harper heaveTucker tells MSU of wrongful termination lawsuitKerr critique shocked, motivated Wolves' Edwards
# Braves to hold open workouts as playoff ramp-upJefferson 'tired' of trade talk for winless VikingsNew rules help MLB draw most fans since 2017Grading the three-team Lillard trade
# Wild-card standings
# Strengths, flaws, picks for U.S. vs. Europe
# Ranking every player in the Ryder Cup
# Why front offices raced to phones after trade
# Sports world reacts to Lillard deal
# Full regular-season grades for all 30 teams
# Shadow Report: Concern for Evans, Wilson and more
# It's not too late to play! Sign up now for free
# Orioles clinch AL East with 100th win of seasonLeBron prepping for 21st season 'like a rookie'Young fan scores helmet after irate Harper heaveTucker tells MSU of wrongful termination lawsuitKerr critique shocked, motivated Wolves' EdwardsBraves to hold open workouts as playoff ramp-upJefferson 'tired' of trade talk for winless VikingsNew rules help MLB draw most fans since 2017Grading the three-team Lillard trade

# %%
browser.quit()
