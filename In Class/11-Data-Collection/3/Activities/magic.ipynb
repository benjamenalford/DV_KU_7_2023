# %% [markdown]
# # Scrape Magic Links

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
from selenium.webdriver.chrome.service import Service
import time

# %%
my_service = Service(executable_path='c:/chrome_driver/chromedriver.exe')
browser = Browser('chrome', service=my_service)

# %% [markdown]
# ## Scrape Book Links from One Page

# %%
# Visit the website
url = 'https://infinite.tcgplayer.com/magic-the-gathering/decks/advanced-search?formats=standard&p=1'
browser.visit(url)

# %%
# Create a BeautifulSoup parser to parse the HTML codepage_s
page_soup = soup(browser.html)

# %%
# find all of the rows
title = page_soup.find('div', class_='grid').find('a', class_='martech-base-link').find('h2',class_='title')
price = page_soup.find('div', class_='grid').find('a', class_='martech-base-link').find('div',class_='market-price')
xurl = page_soup.find('div', class_='grid').find('a', class_='martech-base-link')['href']
deck_base_url ='https://infinite.tcgplayer.com'
print(title, price, xurl)
# Out:
# <h2 class="title martech-text-lg martech-text-bold martech-barlow martech-one-line" data-testid="grid-card__card-grid-deck__title" data-v-45c68ff8="">Samut Red <!-- --></h2> <div class="market-price" data-testid="RouterLink__market-price-template" data-v-df6ff770=""><div class="market-price__new-style" data-v-df6ff770=""><p class="martech-text-sm" data-v-df6ff770="">$47.67</p></div></div> /magic-the-gathering/deck/Samut-Red/478422

# %%
# Extract and store the links for each of the books 
decks = []
browser.visit(url)
for i in range(1,2):
    print(f"getting page {i} of 1")
    time.sleep(1)
    page_soup = soup(browser.html)
   
    result_grid = page_soup.find('div', class_='grid').find_all('a', class_='martech-base-link')
    deck ={}
    for item in result_grid:
        try:
            deck ={}
            deck['title'] = item.find('h2',class_='title').text.strip()
            deck['price'] = item.find('div',class_='market-price').text.strip()
            deck['url'] = item['href']
            card_url = deck_base_url + deck['url'] 
            deck['cards'] = read_cards(card_url)
            decks.append(deck)
        except AttributeError as e:
            pass
    browser.find_by_css('.martech-pagination-next').click()
# Out:
# getting page 1 of 1
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~\.conda\envs\PythonData\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~\.conda\envs\PythonData\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ~\.conda\envs\PythonData\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# ~\.conda\envs\PythonData\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\.conda\envs\PythonData\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     186             raise NewConnectionError(
# --> 187                 self, "Failed to establish a new connection: %s" % e
#     188             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002CDAD7A5948>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2820\2291942146.py in <module>
#      20         except AttributeError as e:
#      21             pass
# ---> 22     browser.find_by_css('.martech-pagination-next').click()
#
# ~\.conda\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by_css(self, css_selector, wait_time)
#     502             original_find="css",
#     503             original_query=css_selector,
# --> 504             wait_time=wait_time,
#     505         )
#     506
#
# ~\.conda\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in find_by(self, finder, finder_kwargs, original_find, original_query, wait_time)
#     274
#     275         while time.time() < end_time:
# --> 276             elem_list = _find(self, finder, finder_kwargs)
#     277
#     278             if elem_list:
#
# ~\.conda\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py in _find(self, finder, finder_kwargs)
#     227
#     228     try:
# --> 229         elements = finder(**finder_kwargs)
#     230         if not isinstance(elements, list):
#     231             elements = [elements]
#
# ~\.conda\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1284         return self.execute(Command.FIND_ELEMENTS, {
#    1285             'using': by,
# -> 1286             'value': value})['value'] or []
#    1287
#    1288     @property
#
# ~\.conda\envs\PythonData\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     426
#     427         params = self._wrap_value(params)
# --> 428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
#     430             self.error_handler.check_response(response)
#
# ~\.conda\envs\PythonData\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     345         data = utils.dump_json(params)
#     346         url = f"{self._url}{path}"
# --> 347         return self._request(command_info[0], url, body=data)
#     348
#     349     def _request(self, method, url, body=None):
#
# ~\.conda\envs\PythonData\lib\site-packages\splinter\driver\webdriver\remote_connection.py in patch_request(self, *args, **kwargs)
#      21             exception = exc
#      22             self._conn = urllib3.PoolManager(timeout=self._timeout)
# ---> 23     raise exception
#
# ~\.conda\envs\PythonData\lib\site-packages\splinter\driver\webdriver\remote_connection.py in patch_request(self, *args, **kwargs)
#      17     for _ in range(3):
#      18         try:
# ---> 19             return old_request(self, *args, **kwargs)
#      20         except (socket.error, HTTPException, IOError, OSError, MaxRetryError) as exc:
#      21             exception = exc
#
# ~\.conda\envs\PythonData\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     367
#     368         if self.keep_alive:
# --> 369             response = self._conn.request(method, url, body=body, headers=headers)
#     370             statuscode = response.status
#     371         else:
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
#      78             return self.request_encode_body(
# ---> 79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#      81
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826                 chunked=chunked,
#     827                 body_pos=body_pos,
# --> 828                 **response_kw
#     829             )
#     830
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826                 chunked=chunked,
#     827                 body_pos=body_pos,
# --> 828                 **response_kw
#     829             )
#     830
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     826                 chunked=chunked,
#     827                 body_pos=body_pos,
# --> 828                 **response_kw
#     829             )
#     830
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
#     787             retries = retries.increment(
# --> 788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789             )
#     790             retries.sleep()
#
# ~\.conda\envs\PythonData\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     590
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#     594         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=64527): Max retries exceeded with url: /session/6725ae8588eee2c1dff27bfc9a989631/elements (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002CDAD7A5948>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))

# %% [markdown]
# ## Scrape Book Links from Multiple Pages

# %%
# Automate clicking the next button
import pandas as pd
pd.DataFrame(decks)
#martech-pagination-next
# Out:
#                                                 title    price  \
# 0                                           Samut Red   $47.67
# 1                              No-Rare Mono-Red Aggro   $11.66
# 2                                      Mono-Red Aggro   $81.11
# 3                                      Esper Midrange  $337.08
# 4                                        Rakdos Anvil  $176.13
# 5   Mono-Blue Cauldron (Magic World Championship X...  $277.36
# 6                                   Mono-White Humans  $239.72
# 7                                      Esper Midrange  $377.99
# 8                                        Bant Control  $271.98
# 9                                         Domain Ramp  $287.57
# 10                                   Golgari Midrange  $448.92
# 11                                   Azorius Soldiers  $188.94
# 12                                     Esper Midrange  $544.79
# 13                                      Esper Legends  $549.44
# 14                                       Bant Control  $271.98
# 15                                   Golgari Midrange  $448.92
# 16                                       Bant Control  $271.98
# 17                                   Azorius Soldiers  $204.32
# 18                              Selesnya Enchantments  $264.00
# 19                                    Four-Color Ramp  $279.92
# 20                                       Bant Control  $271.98
# 21                                     Esper Midrange  $585.89
# 22                                   Mono-White Aggro  $239.72
# 23                                     Mono-Red Aggro   $49.14
# 24                                    Four-Color Ramp  $279.92
# 25                                      Boros Convoke   $48.58
# 26                                     Mono-Red Aggro   $54.95
# 27                                   Golgari Midrange  $463.30
# 28                                  Budget Hydra Ramp   $39.56
# 29                                    Four-Color Ramp  $279.92
# 30                                     Esper Midrange  $403.60
# 31                                   Golgari Midrange  $518.05
# 32                                             Agatha   $62.80
# 33                                     Orcish Amnesia  $986.27
# 34                                    test12313213213  $513.98
# 35                                      zulus20230922    $9.48
# 36                                    Azorius Faeries  $273.01
# 37                                   Tamiyo's Turtles  $125.13
# 38                                            order 1  $143.60
# 39                                    Boros Recruiter  $147.41
# 40                          Boros Recruiter (Updated)  $147.41
# 41                                    Boros Recruiter  $179.23
# 42                                            Golgari  $540.17
# 43                                             Domain  $334.64
#
#                                                   url  \
# 0          /magic-the-gathering/deck/Samut-Red/478422
# 1   /magic-the-gathering/deck/No-Rare-Mono-Red-Agg...
# 2     /magic-the-gathering/deck/Mono-Red-Aggro/478420
# 3     /magic-the-gathering/deck/Esper-Midrange/478415
# 4       /magic-the-gathering/deck/Rakdos-Anvil/478414
# 5   /magic-the-gathering/deck/Mono-Blue-Cauldron-M...
# 6   /magic-the-gathering/deck/Mono-White-Humans/47...
# 13  [Ertai Resurrected, Sheoldred, the Apocalypse,...
# 14  [Horned Loch-Whale, The Wandering Emperor, Lay...
# 15  [Blossoming Tortoise, Bramble Familiar, Glissa...
# 16  [Horned Loch-Whale, The Wandering Emperor, Lay...
# 17  [Harbin, Vanguard Aviator, Knight-Errant of Eo...
# 18  [Generous Visitor, Jukai Naturalist, Katilda, ...
# 19  [Archangel of Wrath, Atraxa, Grand Unifier, To...
# 20  [Horned Loch-Whale, The Wandering Emperor, Lay...
# 21  [Dennick, Pious Apprentice, Faerie Mastermind,...
# 22  [Adeline, Resplendent Cathar, Anointed Peaceke...
# 23  [Bloodthirsty Adversary, Charming Scoundrel, F...
# 24  [Archangel of Wrath, Atraxa, Grand Unifier, To...
# 25  [Charming Scoundrel, Imodane's Recruiter, Iron...
# 26  [Bloodthirsty Adversary, Charming Scoundrel, F...
# 27  [Blossoming Tortoise, Glissa Sunslayer, Gravey...
# 28  [Whisperer of the Wilds, Karametra's Acolyte, ...
# 29  [Archangel of Wrath, Atraxa, Grand Unifier, To...
# 30  [The Wandering Emperor, Farewell, Sunfall, Cut...
# 31  [Graveyard Trespasser, Tenacious Underdog, She...
# 32  [Armorcraft Judge, Burnished Hart, Death Kiss,...
# 33  [Orcish Bowmasters, Sheoldred, the Apocalypse,...
# 34  [Tenacious Underdog, Ao, the Dawn Sky, Raffine...
# 35  [Abzan Falconer, Ardent Elementalist, Bloodlin...
# 36  [Threadbind Clique, Twining Twins, Horned Loch...
# 37  [Shigeki, Jukai Visionary, Colossal Skyturtle,...
# 38  [Adeline, Resplendent Cathar, Coppercoat Vangu...
# 39  [Knight-Errant of Eos, Imodane's Recruiter, Re...
# 40  [Knight-Errant of Eos, Imodane's Recruiter, Re...
# 41  [Voldaren Epicure, Resolute Reinforcements, Yo...
# 42  [Blossoming Tortoise, Mosswood Dreadknight, Te...
# 43  [Topiary Stomper, Archangel of Wrath, Elesh No...

# %%
card_page = soup(browser.html)
card_page.find('div',class_='maindeck').find('li','list__item').find('span',class_='').text
# Out:
# 'Surge Engine'

# %%
def read_cards(url):
    card_browser = Browser('chrome', service=my_service)
    card_browser.visit(url)
    time.sleep(1)
    card_page = soup(card_browser.html)
    card_list = []
    for card in card_page.find('div',class_='maindeck').find_all('li','list__item'):
        the_card =card.find('span',class_='').text.strip()
        card_list.append(the_card)
    card_browser.quit()
    return card_list

# %%
# Out:
# ['Samut, Vizier of Naktamun',
#  'Phoenix Chick',
#  'Monastery Swiftspear',
#  'Feldon, Ronom Excavator',
#  'Squee, Dubious Monarch',
#  'Charming Scoundrel',
#  'Goddric, Cloaked Reveler',
#  'Reckless Stormseeker',
#  'Torch the Tower',
#  'Witchstalker Frenzy',
#  'Monstrous Rage',
#  'Lightning Strike',
#  'Kumano Faces Kakkazan',
#  'Copperline Gorge',
#  'Karplusan Forest',
#  'Rockfall Vale',
#  'Mirrex',
#  'Sokenzan, Crucible of Defiance',
#  'Mountain']

# %%
browser.visit(deck_base_url)

# %%
browser.quit()
